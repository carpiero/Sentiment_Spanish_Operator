# %%
import tweepy
import pandas as pd
import datetime 




tweets_df_total = pd.read_csv('../Row_data/tweets_df_total.csv')

# %%
tweets_df_total = tweets_df_total.drop(columns=['Unnamed: 0'])
tweets_df_total.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   created_at                35 non-null     object
#  1   tweet_id                  35 non-null     int64
#  2   Tweet_Content             35 non-null     object
#  3   name                      35 non-null     object
#  4   user_id                   35 non-null     int64
#  5   user_followers            35 non-null     int64
#  6   user_location             19 non-null     object
#  7   source                    35 non-null     object
#  8   entities                  35 non-null     object
#  9   reply_user_id             35 non-null     object
#  10  reply_status_id           35 non-null     object
#  11  Tweet_Number_of_Likes     35 non-null     int64
#  12  Tweet_Number_of_Retweets  35 non-null     int64
#  13  username                  35 non-null     object
# ...

# %%
tweets_df_total.columns
# Out:
# Index(['created_at', 'tweet_id', 'Tweet_Content', 'name', 'user_id',
#        'user_followers', 'user_location', 'source', 'entities',
#        'reply_user_id', 'reply_status_id', 'Tweet_Number_of_Likes',
#        'Tweet_Number_of_Retweets', 'username', 'GRUPO', 'API'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
sqlitedb_path = '/home/carpiero/ir/Database/twitter.db'
engine = create_engine(f'sqlite:///{sqlitedb_path}', echo=True)



create_table =""" CREATE TABLE IF NOT EXISTS Twitter_Operators (
                                        	created_at DATETIME, 
                                            tweet_id VARCHAR(255), 
                                            Tweet_Content TEXT,
                                            name VARCHAR(255), 
                                            user_id VARCHAR(255),
                                            user_followers INT,
                                            user_location VARCHAR(255),
                                            source VARCHAR(255),
                                            entities TEXT, 
                                            reply_user_id VARCHAR(255), 
                                            reply_status_id VARCHAR(255), 
                                            Tweet_Number_of_Likes INT, 
                                            Tweet_Number_of_Retweets INT, 
                                            username VARCHAR(255), 
                                            GRUPO VARCHAR(255), 
                                            API VARCHAR(255)
                                    ); """
with engine.begin() as conn:
    conn.execute(create_table)
# Out:
# 2020-11-30 12:55:40,501 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-30 12:55:40,502 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-30 12:55:40,504 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-30 12:55:40,505 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-30 12:55:40,505 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-30 12:55:40,506 INFO sqlalchemy.engine.base.Engine  CREATE TABLE IF NOT EXISTS Twitter_Operators (
#                                         	created_at DATETIME,
#                                             tweet_id VARCHAR(255),
#                                             Tweet_Content TEXT,
#                                             name VARCHAR(255),
#                                             user_id VARCHAR(255),
#                                             user_followers INT,
# ...

# %%
from sqlalchemy import create_engine
sqlitedb_path = '/home/carpiero/ir/Database/twitter.db'
engine = create_engine(f'sqlite:///{sqlitedb_path}', echo=True)
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
# 2020-11-30 15:43:34,946 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-30 15:43:34,947 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-30 15:43:34,949 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-30 15:43:34,950 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-30 15:43:34,951 INFO sqlalchemy.engine.base.OptionEngine SELECT name FROM sqlite_master WHERE type='table'
# 2020-11-30 15:43:34,952 INFO sqlalchemy.engine.base.OptionEngine ()
#                 name
# 0  Twitter_Operators

# %%
df_sqlite = pd.read_sql_query("SELECT * FROM Twitter_Operators", engine, coerce_float=True, parse_dates=['created_at'])



df_sqlite.info(memory_usage='deep')



# drop_query = 'drop table Twitter_Operators'     #quitar una tabla
# with engine.begin() as conn:
#     conn.execute(drop_query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2968f5b95dfc> in <module>
# ----> 1 df_sqlite = pd.read_sql_query("SELECT * FROM Twitter_Operators", engine, coerce_float=True, parse_dates=['created_at'])
#       2
#       3
#       4
#       5 df_sqlite.info(memory_usage='deep')
#
# NameError: name 'pd' is not defined

# %%
df_sqlite
# Out:
#               created_at             tweet_id  \
# 0    2020-11-24 23:57:26  1331386476026859520
# 1    2020-11-24 23:52:09  1331385147397206018
# 2    2020-11-24 23:52:09  1331385145883058176
# 3    2020-11-24 23:45:19  1331383426059005952
# 4    2020-11-24 23:30:04  1331379588312797185
# ...                  ...                  ...
# 8766 2020-11-25 20:14:47  1331692831195459585
# 8767 2020-11-25 20:14:46  1331692829618352130
# 8768 2020-11-25 18:19:17  1331663766107381760
# 8769 2020-11-25 18:01:58  1331659408431001604
# 8770 2020-11-25 17:40:00  1331653879046541315
#
#                                           Tweet_Content                  name  \
# 0     RT @DavictusCat: Benvolguts senyors de @vodafo...    Martí Gené i Ramis
# 1     Últimamente falla muchísimo, supongo que será ...                  Liam
# 2     Hola @vodafone_es y @VodafoneTV_es \nDesde hac...                  Liam
# 3     RT @vodafone_es: De camino al trabajo, en el g...  Anna Mudoy Anderberg
# ...

# %%
df_sqlite[['created_at']].resample('D', on='created_at').count()
# Out:
#             created_at
# created_at
# 2020-11-24        4510
# 2020-11-25        4261
